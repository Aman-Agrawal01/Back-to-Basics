# %%
import numpy as np
from linear_reg import *
from logistic_reg import *
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_california_housing, load_breast_cancer

# %% [markdown]
# # Linear Regression

# %%
dataset = fetch_california_housing()
features = dataset['data']
targets = dataset['target'].reshape(-1,1)

split_size = 0.75

X_train, X_test = features[:int(split_size*features.shape[0])], features[int(split_size*features.shape[0]):]
y_train, y_test = targets[:int(split_size*features.shape[0])], targets[int(split_size*features.shape[0]):]

# %%
lr = linear_reg()
lr.fit(X_train,y_train)
print("Weights are ",lr.weights.reshape(-1,))
print("Bias is ",lr.bias.reshape(-1,))

plt.title("Loss v/s Iteration")
plt.xlabel("Iteration")
plt.ylabel("Loss function")
plt.plot(lr.loss_history)
# Out:
# Weights are  [ 4.52940060e-05  2.75361528e-04  5.00792644e-05  9.00953855e-06
#   7.64522362e-04  1.85803566e-05  2.80674380e-04 -9.62094377e-04]
# Bias is  [8.08633599e-06]

# %% [markdown]
# # Logistic Regression

# %%
dataset = load_breast_cancer()
features = dataset['data']
targets = dataset['target'].reshape(-1,1)

split_size = 0.75

X_train, X_test = features[:int(split_size*features.shape[0])], features[int(split_size*features.shape[0]):]
y_train, y_test = targets[:int(split_size*features.shape[0])], targets[int(split_size*features.shape[0]):]

# %%
lr = logistic_reg()
lr.fit(X_train,y_train)
print("Weights are ",lr.weights.reshape(-1,))
print("Bias is ",lr.bias.reshape(-1,))
print("Accuracy is", lr.accuracy(lr.prediction(X_test), y_test))

plt.title("Loss v/s Iteration")
plt.xlabel("Iteration")
plt.ylabel("Loss function")
plt.plot(lr.loss_history)
# Out:
# Weights are  [ 1.24991558e-03  2.13906219e-03  7.63091605e-03  1.03205485e-02
#   1.30226035e-05  3.59561723e-06 -7.27013735e-06 -3.88257831e-06
#   2.49936843e-05  9.77960078e-06  8.13731788e-06  1.79305125e-04
#   3.98155104e-05 -2.40403213e-03  1.10737849e-06  1.81616351e-06
#   2.01992097e-06  8.28804647e-07  3.19122500e-06  5.05092908e-07
#   1.19349852e-03  2.74206169e-03  7.23667376e-03 -8.93736359e-03
#   1.67587064e-05  2.66116010e-06 -1.02102340e-05 -2.17186949e-06
#   3.56906161e-05  1.07122681e-05]
# Bias is  [0.00015675]
# Accuracy is 0.8951048951048951
